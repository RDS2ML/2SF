# %% [markdown]
# ## library requests

# %%
import requests
from pprint import pprint
import json

# %% [markdown]
# ### **Запрос GET**

# %%
url = 'https://www.cbr-xml-daily.ru/daily_json.js' # Определяем значение URL страницы для запроса
response = requests.get(url) # Делаем GET-запрос к ресурсу и результат ответа сохраняем в переменной response
print(response) # проверяем статус запроса 
print(type(response)) # выводим тип данных
# или 
print(response.status_code) # выводим только значение кода 
print(type(response.status_code)) # выводим тип данных
# Out:
# <Response [200]>
# <class 'requests.models.Response'>
# 200
# <class 'int'>

# %% [markdown]
# ### ОТВЕТ

# %%
pprint(response.text) # Выводим содержимое атрибута text переменной response на экран
# Out:
# ('{"Date":"2026-05-22T11:30:00+03:00","PreviousDate":"2026-05-21T11:30:00+03:00","PreviousURL":"\\/\\/www.cbr-xml-daily.ru\\/archive\\/2026\\/05\\/21\\/daily_json.js","Timestamp":"2026-05-22T15:00:00+03:00","Valute":{"AUD":{"ID":"R01010","NumCode":"036","CharCode":"AUD","Nominal":1,"Name":"Австралийский '
#  'доллар","Value":50.438,"Previous":50.3964},"AZN":{"ID":"R01020A","NumCode":"944","CharCode":"AZN","Nominal":1,"Name":"Азербайджанский '
#  'манат","Value":41.6413,"Previous":41.7358},"DZD":{"ID":"R01030","NumCode":"012","CharCode":"DZD","Nominal":100,"Name":"Алжирских '
#  'динаров","Value":53.2786,"Previous":53.3733},"GBP":{"ID":"R01035","NumCode":"826","CharCode":"GBP","Nominal":1,"Name":"Фунт '
#  'стерлингов","Value":95.0925,"Previous":95.0245},"AMD":{"ID":"R01060","NumCode":"051","CharCode":"AMD","Nominal":100,"Name":"Армянских '
#  'драмов","Value":19.2438,"Previous":19.2869},"BHD":{"ID":"R01080","NumCode":"048","CharCode":"BHD","Nominal":1,"Name":"Бахрейнский '
#  'динар","Value":188.2311,"Previous":188.6584},"BYN":{"ID":"R01090B","NumCode":"933","CharCode":"BYN","Nominal":1,"Name":"Белорусский '
#  'рубль","Value":25.9162,"Previous":25.9855},"BOB":{"ID":"R01105","NumCode":"068","CharCode":"BOB","Nominal":1,"Name":"Боливиано","Value":10.2446,"Previous":10.2679},"BRL":{"ID":"R01115","NumCode":"986","CharCode":"BRL","Nominal":1,"Name":"Бразильский '
#  'реал","Value":14.0742,"Previous":14.0845},"HUF":{"ID":"R01135","NumCode":"348","CharCode":"HUF","Nominal":100,"Name":"Форинтов","Value":22.9124,"Previous":22.7574},"VND":{"ID":"R01150","NumCode":"704","CharCode":"VND","Nominal":10000,"Name":"Донгов","Value":28.164,"Previous":28.2279},"HKD":{"ID":"R01200","NumCode":"344","CharCode":"HKD","Nominal":10,"Name":"Гонконгских '
#  'долларов","Value":90.3397,"Previous":90.5679},"GEL":{"ID":"R01210","NumCode":"981","CharCode":"GEL","Nominal":1,"Name":"Лари","Value":26.4626,"Previous":26.5158},"DKK":{"ID":"R01215","NumCode":"208","CharCode":"DKK","Nominal":1,"Name":"Датская '
#  'крона","Value":10.9882,"Previous":11.0323},"AED":{"ID":"R01230","NumCode":"784","CharCode":"AED","Nominal":1,"Name":"Дирхам '
#  'ОАЭ","Value":19.2758,"Previous":19.3195},"USD":{"ID":"R01235","NumCode":"840","CharCode":"USD","Nominal":1,"Name":"Доллар '
#  'США","Value":70.7902,"Previous":70.9509},"EUR":{"ID":"R01239","NumCode":"978","CharCode":"EUR","Nominal":1,"Name":"Евро","Value":83.2746,"Previous":81.9823},"EGP":{"ID":"R01240","NumCode":"818","CharCode":"EGP","Nominal":10,"Name":"Египетских '
#  'фунтов","Value":13.3737,"Previous":13.2772},"INR":{"ID":"R01270","NumCode":"356","CharCode":"INR","Nominal":100,"Name":"Индийских '
#  'рупий","Value":73.4969,"Previous":73.263},"IDR":{"ID":"R01280","NumCode":"360","CharCode":"IDR","Nominal":10000,"Name":"Рупий","Value":40.0284,"Previous":40.0423},"IRR":{"ID":"R01300","NumCode":"364","CharCode":"IRR","Nominal":1000000,"Name":"Иранских '
#  'риалов","Value":48.1017,"Previous":48.1017},"KZT":{"ID":"R01335","NumCode":"398","CharCode":"KZT","Nominal":100,"Name":"Тенге","Value":15.0052,"Previous":15.0342},"CAD":{"ID":"R01350","NumCode":"124","CharCode":"CAD","Nominal":1,"Name":"Канадский '
#  'доллар","Value":51.48,"Previous":51.5744},"QAR":{"ID":"R01355","NumCode":"634","CharCode":"QAR","Nominal":1,"Name":"Катарский '
#  'риал","Value":19.4479,"Previous":19.492},"KGS":{"ID":"R01370","NumCode":"417","CharCode":"KGS","Nominal":100,"Name":"Сомов","Value":80.9493,"Previous":81.1331},"CNY":{"ID":"R01375","NumCode":"156","CharCode":"CNY","Nominal":1,"Name":"Юань","Value":10.398,"Previous":10.4161},"CUP":{"ID":"R01395","NumCode":"192","CharCode":"CUP","Nominal":10,"Name":"Кубинских '
#  'песо","Value":29.4959,"Previous":29.5629},"MDL":{"ID":"R01500","NumCode":"498","CharCode":"MDL","Nominal":10,"Name":"Молдавских '
#  'леев","Value":40.7785,"Previous":40.9709},"MNT":{"ID":"R01503","NumCode":"496","CharCode":"MNT","Nominal":1000,"Name":"Тугриков","Value":19.7931,"Previous":19.8399},"NGN":{"ID":"R01520","NumCode":"566","CharCode":"NGN","Nominal":1000,"Name":"Найр","Value":51.5459,"Previous":51.643},"NZD":{"ID":"R01530","NumCode":"554","CharCode":"NZD","Nominal":1,"Name":"Новозеландский '
#  'доллар","Value":41.4866,"Previous":41.3218},"NOK":{"ID":"R01535","NumCode":"578","CharCode":"NOK","Nominal":10,"Name":"Норвежских '
#  'крон","Value":76.2883,"Previous":76.5969},"OMR":{"ID":"R01540","NumCode":"512","CharCode":"OMR","Nominal":1,"Name":"Оманский '
#  'риал","Value":184.1098,"Previous":184.5277},"PLN":{"ID":"R01565","NumCode":"985","CharCode":"PLN","Nominal":1,"Name":"Злотый","Value":19.3792,"Previous":19.3279},"SAR":{"ID":"R01580","NumCode":"682","CharCode":"SAR","Nominal":1,"Name":"Саудовский '
#  'риял","Value":18.8774,"Previous":18.9202},"RON":{"ID":"R01585F","NumCode":"946","CharCode":"RON","Nominal":1,"Name":"Румынский '
#  'лей","Value":15.6973,"Previous":15.7044},"XDR":{"ID":"R01589","NumCode":"960","CharCode":"XDR","Nominal":1,"Name":"СДР '
#  '(специальные права '
#  'заимствования)","Value":96.7157,"Previous":96.987},"SGD":{"ID":"R01625","NumCode":"702","CharCode":"SGD","Nominal":1,"Name":"Сингапурский '
#  'доллар","Value":55.3308,"Previous":55.3655},"TJS":{"ID":"R01670","NumCode":"972","CharCode":"TJS","Nominal":10,"Name":"Сомони","Value":76.2119,"Previous":76.1455},"THB":{"ID":"R01675","NumCode":"764","CharCode":"THB","Nominal":10,"Name":"Батов","Value":21.6722,"Previous":21.6849},"BDT":{"ID":"R01685","NumCode":"050","CharCode":"BDT","Nominal":100,"Name":"Так","Value":57.6405,"Previous":57.8065},"TRY":{"ID":"R01700J","NumCode":"949","CharCode":"TRY","Nominal":10,"Name":"Турецких '
#  'лир","Value":15.5412,"Previous":15.5975},"TMT":{"ID":"R01710A","NumCode":"934","CharCode":"TMT","Nominal":1,"Name":"Новый '
#  'туркменский '
#  'манат","Value":20.2258,"Previous":20.2717},"UZS":{"ID":"R01717","NumCode":"860","CharCode":"UZS","Nominal":10000,"Name":"Узбекских '
#  'сумов","Value":58.8877,"Previous":58.7528},"UAH":{"ID":"R01720","NumCode":"980","CharCode":"UAH","Nominal":10,"Name":"Гривен","Value":16.0035,"Previous":16.0424},"CZK":{"ID":"R01760","NumCode":"203","CharCode":"CZK","Nominal":10,"Name":"Чешских '
#  'крон","Value":33.7981,"Previous":33.8458},"SEK":{"ID":"R01770","NumCode":"752","CharCode":"SEK","Nominal":10,"Name":"Шведских '
#  'крон","Value":75.4922,"Previous":75.5752},"CHF":{"ID":"R01775","NumCode":"756","CharCode":"CHF","Nominal":1,"Name":"Швейцарский '
#  'франк","Value":89.9609,"Previous":89.7885},"ETB":{"ID":"R01800","NumCode":"230","CharCode":"ETB","Nominal":100,"Name":"Эфиопских '
#  'быров","Value":44.3479,"Previous":45.0228},"RSD":{"ID":"R01805F","NumCode":"941","CharCode":"RSD","Nominal":100,"Name":"Сербских '
#  'динаров","Value":70.0797,"Previous":70.1108},"ZAR":{"ID":"R01810","NumCode":"710","CharCode":"ZAR","Nominal":10,"Name":"Рэндов","Value":42.979,"Previous":42.586},"KRW":{"ID":"R01815","NumCode":"410","CharCode":"KRW","Nominal":1000,"Name":"Вон","Value":46.8902,"Previous":47.1811},"JPY":{"ID":"R01820","NumCode":"392","CharCode":"JPY","Nominal":100,"Name":"Иен","Value":44.5586,"Previous":44.6232},"MMK":{"ID":"R02005","NumCode":"104","CharCode":"MMK","Nominal":1000,"Name":"Кьятов","Value":33.7096,"Previous":33.7861}}}')

# %%
currencies = response.json() # Применяем метод json()
pprint(currencies) # Выводим результат на экран
# Out:
# {'Date': '2026-05-22T11:30:00+03:00',
#  'PreviousDate': '2026-05-21T11:30:00+03:00',
#  'PreviousURL': '//www.cbr-xml-daily.ru/archive/2026/05/21/daily_json.js',
#  'Timestamp': '2026-05-22T15:00:00+03:00',
#  'Valute': {'AED': {'CharCode': 'AED',
#                     'ID': 'R01230',
#                     'Name': 'Дирхам ОАЭ',
#                     'Nominal': 1,
#                     'NumCode': '784',
#                     'Previous': 19.3195,
#                     'Value': 19.2758},
#             'AMD': {'CharCode': 'AMD',
#                     'ID': 'R01060',
#                     'Name': 'Армянских драмов',
#                     'Nominal': 100,
#                     'NumCode': '051',
#                     'Previous': 19.2869,
#                     'Value': 19.2438},
#             'AUD': {'CharCode': 'AUD',
#                     'ID': 'R01010',
#                     'Name': 'Австралийский доллар',
#                     'Nominal': 1,
#                     'NumCode': '036',
#                     'Previous': 50.3964,
#                     'Value': 50.438},
#             'AZN': {'CharCode': 'AZN',
#                     'ID': 'R01020A',
#                     'Name': 'Азербайджанский манат',
#                     'Nominal': 1,
#                     'NumCode': '944',
#                     'Previous': 41.7358,
#                     'Value': 41.6413},
#             'BDT': {'CharCode': 'BDT',
#                     'ID': 'R01685',
#                     'Name': 'Так',
#                     'Nominal': 100,
#                     'NumCode': '050',
#                     'Previous': 57.8065,
#                     'Value': 57.6405},
#             'BHD': {'CharCode': 'BHD',
#                     'ID': 'R01080',
#                     'Name': 'Бахрейнский динар',
#                     'Nominal': 1,
#                     'NumCode': '048',
#                     'Previous': 188.6584,
#                     'Value': 188.2311},
#             'BOB': {'CharCode': 'BOB',
#                     'ID': 'R01105',
#                     'Name': 'Боливиано',
#                     'Nominal': 1,
#                     'NumCode': '068',
#                     'Previous': 10.2679,
#                     'Value': 10.2446},
#             'BRL': {'CharCode': 'BRL',
#                     'ID': 'R01115',
#                     'Name': 'Бразильский реал',
#                     'Nominal': 1,
#                     'NumCode': '986',
#                     'Previous': 14.0845,
#                     'Value': 14.0742},
#             'BYN': {'CharCode': 'BYN',
#                     'ID': 'R01090B',
#                     'Name': 'Белорусский рубль',
#                     'Nominal': 1,
#                     'NumCode': '933',
#                     'Previous': 25.9855,
#                     'Value': 25.9162},
#             'CAD': {'CharCode': 'CAD',
#                     'ID': 'R01350',
#                     'Name': 'Канадский доллар',
#                     'Nominal': 1,
#                     'NumCode': '124',
#                     'Previous': 51.5744,
#                     'Value': 51.48},
#             'CHF': {'CharCode': 'CHF',
#                     'ID': 'R01775',
#                     'Name': 'Швейцарский франк',
#                     'Nominal': 1,
#                     'NumCode': '756',
#                     'Previous': 89.7885,
#                     'Value': 89.9609},
#             'CNY': {'CharCode': 'CNY',
#                     'ID': 'R01375',
#                     'Name': 'Юань',
#                     'Nominal': 1,
#                     'NumCode': '156',
#                     'Previous': 10.4161,
#                     'Value': 10.398},
#             'CUP': {'CharCode': 'CUP',
#                     'ID': 'R01395',
#                     'Name': 'Кубинских песо',
#                     'Nominal': 10,
#                     'NumCode': '192',
#                     'Previous': 29.5629,
#                     'Value': 29.4959},
#             'CZK': {'CharCode': 'CZK',
#                     'ID': 'R01760',
#                     'Name': 'Чешских крон',
#                     'Nominal': 10,
#                     'NumCode': '203',
#                     'Previous': 33.8458,
#                     'Value': 33.7981},
#             'DKK': {'CharCode': 'DKK',
#                     'ID': 'R01215',
#                     'Name': 'Датская крона',
#                     'Nominal': 1,
#                     'NumCode': '208',
#                     'Previous': 11.0323,
#                     'Value': 10.9882},
#             'DZD': {'CharCode': 'DZD',
#                     'ID': 'R01030',
#                     'Name': 'Алжирских динаров',
#                     'Nominal': 100,
#                     'NumCode': '012',
#                     'Previous': 53.3733,
#                     'Value': 53.2786},
#             'EGP': {'CharCode': 'EGP',
#                     'ID': 'R01240',
#                     'Name': 'Египетских фунтов',
#                     'Nominal': 10,
#                     'NumCode': '818',
#                     'Previous': 13.2772,
#                     'Value': 13.3737},
#             'ETB': {'CharCode': 'ETB',
#                     'ID': 'R01800',
#                     'Name': 'Эфиопских быров',
#                     'Nominal': 100,
#                     'NumCode': '230',
#                     'Previous': 45.0228,
#                     'Value': 44.3479},
#             'EUR': {'CharCode': 'EUR',
#                     'ID': 'R01239',
#                     'Name': 'Евро',
#                     'Nominal': 1,
#                     'NumCode': '978',
#                     'Previous': 81.9823,
#                     'Value': 83.2746},
#             'GBP': {'CharCode': 'GBP',
#                     'ID': 'R01035',
#                     'Name': 'Фунт стерлингов',
#                     'Nominal': 1,
#                     'NumCode': '826',
#                     'Previous': 95.0245,
#                     'Value': 95.0925},
#             'GEL': {'CharCode': 'GEL',
#                     'ID': 'R01210',
#                     'Name': 'Лари',
#                     'Nominal': 1,
#                     'NumCode': '981',
#                     'Previous': 26.5158,
#                     'Value': 26.4626},
#             'HKD': {'CharCode': 'HKD',
#                     'ID': 'R01200',
#                     'Name': 'Гонконгских долларов',
#                     'Nominal': 10,
#                     'NumCode': '344',
#                     'Previous': 90.5679,
#                     'Value': 90.3397},
#             'HUF': {'CharCode': 'HUF',
#                     'ID': 'R01135',
#                     'Name': 'Форинтов',
#                     'Nominal': 100,
#                     'NumCode': '348',
#                     'Previous': 22.7574,
#                     'Value': 22.9124},
#             'IDR': {'CharCode': 'IDR',
#                     'ID': 'R01280',
#                     'Name': 'Рупий',
#                     'Nominal': 10000,
#                     'NumCode': '360',
#                     'Previous': 40.0423,
#                     'Value': 40.0284},
#             'INR': {'CharCode': 'INR',
#                     'ID': 'R01270',
#                     'Name': 'Индийских рупий',
#                     'Nominal': 100,
#                     'NumCode': '356',
#                     'Previous': 73.263,
#                     'Value': 73.4969},
#             'IRR': {'CharCode': 'IRR',
#                     'ID': 'R01300',
#                     'Name': 'Иранских риалов',
#                     'Nominal': 1000000,
#                     'NumCode': '364',
#                     'Previous': 48.1017,
#                     'Value': 48.1017},
#             'JPY': {'CharCode': 'JPY',
#                     'ID': 'R01820',
#                     'Name': 'Иен',
#                     'Nominal': 100,
#                     'NumCode': '392',
#                     'Previous': 44.6232,
#                     'Value': 44.5586},
#             'KGS': {'CharCode': 'KGS',
#                     'ID': 'R01370',
#                     'Name': 'Сомов',
#                     'Nominal': 100,
#                     'NumCode': '417',
#                     'Previous': 81.1331,
#                     'Value': 80.9493},
#             'KRW': {'CharCode': 'KRW',
#                     'ID': 'R01815',
#                     'Name': 'Вон',
#                     'Nominal': 1000,
#                     'NumCode': '410',
#                     'Previous': 47.1811,
#                     'Value': 46.8902},
#             'KZT': {'CharCode': 'KZT',
#                     'ID': 'R01335',
#                     'Name': 'Тенге',
#                     'Nominal': 100,
#                     'NumCode': '398',
#                     'Previous': 15.0342,
#                     'Value': 15.0052},
#             'MDL': {'CharCode': 'MDL',
#                     'ID': 'R01500',
#                     'Name': 'Молдавских леев',
#                     'Nominal': 10,
#                     'NumCode': '498',
#                     'Previous': 40.9709,
#                     'Value': 40.7785},
#             'MMK': {'CharCode': 'MMK',
#                     'ID': 'R02005',
#                     'Name': 'Кьятов',
#                     'Nominal': 1000,
#                     'NumCode': '104',
#                     'Previous': 33.7861,
#                     'Value': 33.7096},
#             'MNT': {'CharCode': 'MNT',
#                     'ID': 'R01503',
#                     'Name': 'Тугриков',
#                     'Nominal': 1000,
#                     'NumCode': '496',
#                     'Previous': 19.8399,
#                     'Value': 19.7931},
#             'NGN': {'CharCode': 'NGN',
#                     'ID': 'R01520',
#                     'Name': 'Найр',
#                     'Nominal': 1000,
#                     'NumCode': '566',
#                     'Previous': 51.643,
#                     'Value': 51.5459},
#             'NOK': {'CharCode': 'NOK',
#                     'ID': 'R01535',
#                     'Name': 'Норвежских крон',
#                     'Nominal': 10,
#                     'NumCode': '578',
#                     'Previous': 76.5969,
#                     'Value': 76.2883},
#             'NZD': {'CharCode': 'NZD',
#                     'ID': 'R01530',
#                     'Name': 'Новозеландский доллар',
#                     'Nominal': 1,
#                     'NumCode': '554',
#                     'Previous': 41.3218,
#                     'Value': 41.4866},
#             'OMR': {'CharCode': 'OMR',
#                     'ID': 'R01540',
#                     'Name': 'Оманский риал',
#                     'Nominal': 1,
#                     'NumCode': '512',
#                     'Previous': 184.5277,
#                     'Value': 184.1098},
#             'PLN': {'CharCode': 'PLN',
#                     'ID': 'R01565',
#                     'Name': 'Злотый',
#                     'Nominal': 1,
#                     'NumCode': '985',
#                     'Previous': 19.3279,
#                     'Value': 19.3792},
#             'QAR': {'CharCode': 'QAR',
#                     'ID': 'R01355',
#                     'Name': 'Катарский риал',
#                     'Nominal': 1,
#                     'NumCode': '634',
#                     'Previous': 19.492,
#                     'Value': 19.4479},
#             'RON': {'CharCode': 'RON',
#                     'ID': 'R01585F',
#                     'Name': 'Румынский лей',
#                     'Nominal': 1,
#                     'NumCode': '946',
#                     'Previous': 15.7044,
#                     'Value': 15.6973},
#             'RSD': {'CharCode': 'RSD',
#                     'ID': 'R01805F',
#                     'Name': 'Сербских динаров',
#                     'Nominal': 100,
#                     'NumCode': '941',
#                     'Previous': 70.1108,
#                     'Value': 70.0797},
#             'SAR': {'CharCode': 'SAR',
#                     'ID': 'R01580',
#                     'Name': 'Саудовский риял',
#                     'Nominal': 1,
#                     'NumCode': '682',
#                     'Previous': 18.9202,
#                     'Value': 18.8774},
#             'SEK': {'CharCode': 'SEK',
#                     'ID': 'R01770',
#                     'Name': 'Шведских крон',
#                     'Nominal': 10,
#                     'NumCode': '752',
#                     'Previous': 75.5752,
#                     'Value': 75.4922},
#             'SGD': {'CharCode': 'SGD',
#                     'ID': 'R01625',
#                     'Name': 'Сингапурский доллар',
#                     'Nominal': 1,
#                     'NumCode': '702',
#                     'Previous': 55.3655,
#                     'Value': 55.3308},
#             'THB': {'CharCode': 'THB',
#                     'ID': 'R01675',
#                     'Name': 'Батов',
#                     'Nominal': 10,
#                     'NumCode': '764',
#                     'Previous': 21.6849,
#                     'Value': 21.6722},
#             'TJS': {'CharCode': 'TJS',
#                     'ID': 'R01670',
#                     'Name': 'Сомони',
#                     'Nominal': 10,
#                     'NumCode': '972',
#                     'Previous': 76.1455,
#                     'Value': 76.2119},
#             'TMT': {'CharCode': 'TMT',
#                     'ID': 'R01710A',
#                     'Name': 'Новый туркменский манат',
#                     'Nominal': 1,
#                     'NumCode': '934',
#                     'Previous': 20.2717,
#                     'Value': 20.2258},
#             'TRY': {'CharCode': 'TRY',
#                     'ID': 'R01700J',
#                     'Name': 'Турецких лир',
#                     'Nominal': 10,
#                     'NumCode': '949',
#                     'Previous': 15.5975,
#                     'Value': 15.5412},
#             'UAH': {'CharCode': 'UAH',
#                     'ID': 'R01720',
#                     'Name': 'Гривен',
#                     'Nominal': 10,
#                     'NumCode': '980',
#                     'Previous': 16.0424,
#                     'Value': 16.0035},
#             'USD': {'CharCode': 'USD',
#                     'ID': 'R01235',
#                     'Name': 'Доллар США',
#                     'Nominal': 1,
#                     'NumCode': '840',
#                     'Previous': 70.9509,
#                     'Value': 70.7902},
#             'UZS': {'CharCode': 'UZS',
#                     'ID': 'R01717',
#                     'Name': 'Узбекских сумов',
#                     'Nominal': 10000,
#                     'NumCode': '860',
#                     'Previous': 58.7528,
#                     'Value': 58.8877},
#             'VND': {'CharCode': 'VND',
#                     'ID': 'R01150',
#                     'Name': 'Донгов',
#                     'Nominal': 10000,
#                     'NumCode': '704',
#                     'Previous': 28.2279,
#                     'Value': 28.164},
#             'XDR': {'CharCode': 'XDR',
#                     'ID': 'R01589',
#                     'Name': 'СДР (специальные права заимствования)',
#                     'Nominal': 1,
#                     'NumCode': '960',
#                     'Previous': 96.987,
#                     'Value': 96.7157},
#             'ZAR': {'CharCode': 'ZAR',
#                     'ID': 'R01810',
#                     'Name': 'Рэндов',
#                     'Nominal': 10,
#                     'NumCode': '710',
#                     'Previous': 42.586,
#                     'Value': 42.979}}}

# %%
pprint(currencies['Valute']['EUR']) # Выводим на экран информацию о валюте евро
print('-'*22)
pprint(currencies['Valute']['CZK']['Name'])
# Out:
# {'CharCode': 'EUR',
#  'ID': 'R01239',
#  'Name': 'Евро',
#  'Nominal': 1,
#  'NumCode': '978',
#  'Previous': 81.9823,
#  'Value': 83.2746}
# ----------------------
# 'Чешских крон'
