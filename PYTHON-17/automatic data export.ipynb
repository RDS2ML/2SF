# %% [markdown]
# ## **automatic data export**

# %%
import schedule
import time

# %% [markdown]
# #### **Постнавнока задачи**

# %%
def simple_task():
    print('My first shedule task!')
    return

schedule.every(1).minute.do(simple_task) # Каждую минуту выполнять
# schedule.every(1).hour.do(simple_task) # Каждый час выполнять
# Out:
# Every 1 minute do simple_task() (last run: [never], next run: 2026-05-25 16:25:57)

# %% [markdown]
# #### **Выполнение функции**

# %%
#while True: 
    #schedule.run_pending() 
    #time.sleep(1)
